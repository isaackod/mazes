# %%
import generation_algos as ga
from maze_utils import *

# %%
my_tree_maze = ga.BinaryTree(15, 30)
my_tree_maze.on()
print(my_tree_maze)
# Out:
# +---+---+---+---+---+---+---+---+---+---+---+---+---+---+---+---+---+---+---+---+---+---+---+---+---+---+---+---+---+---+
# |   |   |       |   |   |   |   |           |       |           |       |   |   |           |   |       |   |   |   |   |
# +   +   +---+   +   +   +   +   +---+---+   +---+   +---+---+   +---+   +   +   +---+---+   +   +---+   +   +   +   +   +
# |   |   |   |   |       |           |           |   |   |       |       |           |               |   |   |   |   |   |
# +   +   +   +   +---+   +---+---+   +---+---+   +   +   +---+   +---+   +---+---+   +---+---+---+   +   +   +   +   +   +
# |   |   |           |   |           |       |           |   |           |       |   |       |   |       |   |   |   |   |
# +   +   +---+---+   +   +---+---+   +---+   +---+---+   +   +---+---+   +---+   +   +---+   +   +---+   +   +   +   +   +
# |   |   |   |   |       |   |       |   |               |       |       |   |   |       |   |           |           |   |
# ...

# %%
my_sidewinder = ga.Sidewinder(50, 9, 60)
my_sidewinder.on()
print(my_sidewinder)
# Out:
# +---+---+---+---+---+---+---+---+---+
# |               |                   |
# +---+---+---+   +---+---+---+---+   +
# |           |               |       |
# +---+---+   +   +---+---+---+---+   +
# |           |   |               |   |
# +   +---+---+   +   +---+---+---+   +
# |           |   |                   |
# +   +---+---+   +---+---+---+---+   +
# |           |           |   |       |
# +---+---+   +---+   +---+   +---+   +
# |                   |       |       |
# +---+---+---+---+   +---+   +---+   +
# |           |   |                   |
# +   +---+---+   +---+---+---+---+   +
# |   |       |   |       |   |       |
# +   +   +---+   +   +---+   +---+   +
# |               |       |           |
# +   +---+---+---+   +---+---+---+   +
# |           |       |               |
# +   +---+---+---+   +---+---+---+   +
# |   |   |                       |   |
# +   +   +---+---+   +---+---+---+   +
# |       |               |   |   |   |
# +---+   +   +---+---+---+   +   +   +
# ...

# %%
from path import Path

# %%
path = Path('.')
save_maze_json(my_sidewinder,"sidewinder")
save_maze_json(my_tree_maze,"tree_maze")

# %%
my_tree_maze
# Out:
# +---+---+---+---+---+---+---+---+---+---+---+---+---+---+---+---+---+---+---+---+---+---+---+---+---+---+---+---+---+---+
# |   |   |       |   |   |   |   |           |       |           |       |   |   |           |   |       |   |   |   |   |
# +   +   +---+   +   +   +   +   +---+---+   +---+   +---+---+   +---+   +   +   +---+---+   +   +---+   +   +   +   +   +
# |   |   |   |   |       |           |           |   |   |       |       |           |               |   |   |   |   |   |
# +   +   +   +   +---+   +---+---+   +---+---+   +   +   +---+   +---+   +---+---+   +---+---+---+   +   +   +   +   +   +
# |   |   |           |   |           |       |           |   |           |       |   |       |   |       |   |   |   |   |
# +   +   +---+---+   +   +---+---+   +---+   +---+---+   +   +---+---+   +---+   +   +---+   +   +---+   +   +   +   +   +
# |   |   |   |   |       |   |       |   |               |       |       |   |   |       |   |           |           |   |
# ...
