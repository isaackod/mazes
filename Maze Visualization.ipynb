# %%
import generation_algos as ga

# %%
my_tree_maze = ga.BinaryTree(15, 15)
my_tree_maze.on()
print(my_tree_maze)

my_sidewinder = ga.Sidewinder(6, 6, 70)
my_sidewinder.on()
print(my_sidewinder)
# Out:
# +---+---+---+---+---+---+---+---+---+---+---+---+---+---+---+
# |                   |       |   |   |   |   |   |   |   |   |
# +---+---+---+---+   +---+   +   +   +   +   +   +   +   +   +
# |   |           |   |               |       |       |   |   |
# +   +---+---+   +   +---+---+---+   +---+   +---+   +   +   +
# |   |   |   |                   |       |           |       |
# +   +   +   +---+---+---+---+   +---+   +---+---+   +---+   +
# |                           |   |   |   |   |   |   |   |   |
# +---+---+---+---+---+---+   +   +   +   +   +   +   +   +   +
# |   |   |           |   |   |                   |   |   |   |
# +   +   +---+---+   +   +   +---+---+---+---+   +   +   +   +
# |                       |   |       |       |   |           |
# +---+---+---+---+---+   +   +---+   +---+   +   +---+---+   +
# |   |       |                   |   |       |       |       |
# +   +---+   +---+---+---+---+   +   +---+   +---+   +---+   +
# ...
